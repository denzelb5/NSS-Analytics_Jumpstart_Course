# %%
import pandas as pd

# %%
weather_2018 = pd.read_csv('../data/weather_2018.csv')

# %%
weather_2018
# Out:
#            STATION                             NAME        DATE  AWND  DAPR  \
# 0      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-01   NaN   NaN
# 1      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-02   NaN   NaN
# 2      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-03   NaN   NaN
# 3      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-04   NaN   NaN
# 4      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-05   NaN   NaN
# 5      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-06   NaN   NaN
# 6      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-07   NaN   NaN
# 7      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-08   NaN   NaN
# 8      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-09   NaN   NaN
# 9      US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-10   NaN   NaN
# 10     US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  2018-01-11   NaN   NaN
# ...
